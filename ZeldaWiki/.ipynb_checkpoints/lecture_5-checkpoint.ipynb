# %%
# import libraries
import pandas as pd
import networkx as nx
import re
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import powerlaw

# %% [markdown]
# # Part A: Visualisation

# %% [markdown]
# ## Exercise 1: Build the right graph for visualization:

# %% [markdown]
# ## 1. Use NetworkX DiGraph to store the network of characters.
# Remember that characters are linked if they have a corresponding link between their Zelda Wiki contents.

# %%
df = pd.read_csv("./ZeldaBotW_nodes_w_attributes_enriched.csv")
df.head()
# Out:
#      Name  Role    Race   Gender
# 0  Baddek  Ally  Hylian     Male
# 1  Bamboo  Ally   Horse  Unknown
# 2   Banji  Ally  Hylian   Female
# 3  Baumar  Ally  Hylian     Male
# 4   Bayge  Ally   Goron     Male

# %% [markdown]
# ### Add each character as node&Store their attributes

# %%
# count the number of words in each character's page
each_page_length = []
for i in range(0,df.shape[0]):
    node = df.Name.values[i]
    pages_path = "./CharacterDescription/"
    with open(pages_path+node+".txt","r") as f:
        node_description = f.read()
        #  split the sentences into words 
        per_word = node_description.split()
        each_page_length.append(len(per_word))

# %%
DiG = nx.DiGraph()

#store 'role','race','gender','content length' as node attributes
for i in range(0,df.shape[0]):
    DiG.add_node(df.Name.values[i],\
                 role= df.Role.values[i],
                 race= df.Race.values[i],
                 gender= df.Gender.values[i],
                 content_length = each_page_length[i])

# %%
len(DiG.nodes())
# Out:
# 656

# %% [markdown]
# ### Prepare regx to catch links

# %%
# direct links
pattern1 = "\[\[(.*?)(?:\|.*?)?\]\]" 
# links using text & links using plural terms
pattern2 = "\{\{(Term|Plural)\|BotW\|(.*?)\}\}"
# links to pages that have parentheses
pattern3 = "\{\{(Term|Plural)\|Series\|(.*?)\}\}"

# %%
# get character name from pattern2,3
def get_name(link):
    lst = []
    for i in link:
        # For structure like this {{Term|Series|Princess Zelda|link|display=Zelda}}
        # it's easy to get the name by split and index the third word
        lst.append(i[1].split('|')[0])
    return lst

# %% [markdown]
# ### Iterate all nodes to find links in the txt pages we got previously

# %%
for node in DiG.nodes():
    pages_path = "./CharacterDescription/"
    # open each character's wiki page
    with open(pages_path+node+".txt","r") as f:
        node_description = f.read()
    # find node's links in their page
    link1 = re.findall(pattern1,node_description)
    link2 = re.findall(pattern2,node_description)
    link2 = get_name(link2)
    link3 = re.findall(pattern3,node_description)
    link3 = get_name(link3)
    links = link1+link2+link3

    for link in links:
        # check if the target is a character
        if link in DiG.nodes():
            DiG.add_edge(node,link)

# %%
# num of edges
len(DiG.edges())
# Out:
# 1929

# %%
nx.draw(DiG,node_size=20)

# %% [markdown]
# **discard isolated nodes**

# %%
DiG.remove_nodes_from(list(nx.isolates(DiG)))

# %%
print('DiG now has',len(DiG.nodes()),'nodes')
# Out:
# DiG now has 536 nodes

# %% [markdown]
# **use weakly connected component to extract the largest component.**

# %%
largest = max(nx.weakly_connected_components(DiG),key=len)
dir_larG = DiG.subgraph(largest)

# %%
nx.draw(dir_larG,node_size=20)

# %%
len(largest)
# Out:
# 519

# %% [markdown]
# # Exercise 2: build a simple visualization of the network

# %% [markdown]
# ##  convert our network to undirected graph

# %%
larG = dir_larG.to_undirected()

# %% [markdown]
# ##  draw the resulting undirected network.

# %% [markdown]
# ### set Node color depending on the role attribute**

# %% [markdown]
# **distribute characters to three list based on their role**

# %%
# extract nodes with specific setting of the attribute
ally_nodes = [n for (n,rl) in \
    nx.get_node_attributes(larG,'role').items() if rl == 'Ally']
enemy_nodes = [n for (n,rl) in \
    nx.get_node_attributes(larG,'role').items() if rl in ('Enemy','Boss')]
# find all the remaining nodes.
other_nodes = list(set(larG.nodes()) - set(ally_nodes) - set(enemy_nodes))

# %% [markdown]
# **set corresponding color list**

# %%
nodelst = ally_nodes+enemy_nodes+other_nodes
colors = []
for i in range(len(nodelst)):
    if i < len(ally_nodes):
        colors.append('#41b6e6')
    elif i < len(ally_nodes+enemy_nodes):
        colors.append('#e74c3c')
    else:
        colors.append('#7A57D1')

# %% [markdown]
# **get the dictionary of nodes and their degrees**

# %%
d = dict(larG.degree)

# %% [markdown]
# **set nodes color and size using '\*\*kwargs'**

# %%
options_node = {
    'nodelist': nodelst,
    'node_color': colors,
    # set node-size depending on the node degree
    'node_size':[v*10 for v in d.values()],
    'alpha':0.9,
}

# %% [markdown]
# **use kamada_kawai_layout to draw the undir network**

# %%
plt.figure(figsize=(12,12))
pos = nx.kamada_kawai_layout(larG)
nx.draw(larG, pos, **options_node)
plt.show()

# %% [markdown]
# # Exercise 3: observe structure with ForceAtlas package

# %% [markdown]
# ## install ForceAtlas2 package
# ForceAtlas2 algorithm helps to determine the positions of the nodes<br>
# use command <code>pip install fa2</code> to install it

# %%
# import fa2
from fa2 import ForceAtlas2

# %% [markdown]
# ## visualise the network by fa2

# %%
# Load the graph edges and compute the node positions using ForceAtlas2
G = larG
forceatlas2 = ForceAtlas2()
positions = forceatlas2.forceatlas2_networkx_layout(G, pos=None, iterations=200)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:01<00:00, 191.86it/s]
# BarnesHut Approximation  took  0.20  seconds
# Repulsion forces  took  0.78  seconds
# Gravitational forces  took  0.01  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.02  seconds

# %% [markdown]
# ### Set edge colors
# if an edge connects allies assign color_a, if the edge connects enemies/bosses assign color_b, in other cases assign color_c (i.e. when allies connect to either enemies or bosses).

# %%
edge_colors = []
for i,j in G.edges():
    if i in ally_nodes and j in ally_nodes:
        edge_colors.append('#41b5e0')
    elif i in enemy_nodes and j in enemy_nodes:
        edge_colors.append('#f06966')
    else:
        edge_colors.append('#42218E')

# %%
plt.figure(figsize=(12,12))

# draw nodes
nx.draw_networkx_nodes(G,positions, **options_node)

# draw edges
options_edge = {
    'edge_color':edge_colors,
}
nx.draw_networkx_edges(G,positions, **options_edge)

# cancel axis
plt.axis('off')
plt.show()

# %% [markdown]
# ## Describe the structure you observe.

# %% [markdown]
# **Can you identify nodes with a privileged position in the network?**<br>
# * Yes, it's very obvious that the more degree a node has, the larger it would be.
# * As the network shown, blue represents ally, red represents enemy.<br>
# * We can see from the dictionary below that our main character 'Link' has leading amout of degrees than other characters, which indicates that he is the most important character.
# * Similarly, the biggst antagonist, 'Calamity Ganon', has second most degree amount, so it's natural to find the second largest node is a red one.

# %%
def sort_by_value(d):
    return sorted(d.items(), key=lambda k: k[1],reverse=True)  # k[1] get the dict value

sort_by_value(dict(larG.degree))
# Out:
# [('Link', 389),
#  ('Calamity Ganon', 101),
#  ('Hylia', 67),
#  ('Princess Zelda', 27),
#  ('Riju', 24),
#  ('Bokoblin', 23),
#  ('Purah', 22),
#  ('Mipha', 19),
#  ('Impa', 18),
#  ('Sidon', 17),
#  ('Kilton', 16),
#  ('Moblin', 16),
#  ('Ashai', 15),
#  ('Kass', 14),
#  ('Traysi', 14),
#  ('Lizalfos', 14),
#  ('Lynel', 14),
#  ('King Rhoam', 13),
#  ('King Dorephan', 13),
#  ('Daruk', 12),
#  ('Revali', 12),
#  ('Urbosa', 12),
#  ('Robbie', 12),
#  ('Electric Lizalfos', 12),
#  ('Fire-Breath Lizalfos', 12),
#  ('Stalizalfos', 12),
#  ('Stone Talus', 12),
#  ('Blue Bokoblin', 11),
#  ('Fire Wizzrobe', 11),
#  ('Guardian Stalker', 11),
#  ('Silver Lizalfos', 11),
#  ('Stalmoblin', 11),
#  ('Yiga Footsoldier', 11),
#  ('Hinox', 11),
#  ('Hudson', 10),
#  ('Old Man', 10),
#  ('Bludo', 10),
#  ('Vilia', 10),
#  ('Teba', 10),
#  ('Dorian', 10),
#  ('Cursed Lizalfos', 10),
#  ('Banji', 9),
#  ('Bolson', 9),
#  ('Yunobo', 9),
#  ('Azu', 9),
#  ('Nanna', 9),
#  ('Black Bokoblin', 9),
#  ('Blue Lizalfos', 9),
#  ('Golden Lizalfos', 9),
#  ('Golden Lynel', 9),
#  ('Guardian Turret', 9),
#  ('Ice-Breath Lizalfos', 9),
#  ('Stalkoblin', 9),
#  ('Thunder Wizzrobe', 9),
#  ('Igneo Talus', 9),
#  ('Frost Talus', 9),
#  ('Windblight Ganon', 9),
#  ('Fireblight Ganon', 9),
#  ('Thunderblight Ganon', 9),
#  ('Waterblight Ganon', 9),
#  ('Chork', 8),
#  ('Greyson', 8),
#  ('Jerrin', 8),
#  ('Canni', 8),
#  ('Pearle', 8),
#  ('Kheel', 8),
#  ('Harth', 8),
#  ('Tula', 8),
#  ('Trello', 8),
#  ('Tumbo', 8),
#  ('Celessa', 8),
#  ('Teli', 8),
#  ('Nikki', 8),
#  ('Paya', 8),
#  ('Steen', 8),
#  ('Black Lizalfos', 8),
#  ('Blizzrobe', 8),
#  ('Electric Keese', 8),
#  ('Golden Moblin', 8),
#  ('Guardian Skywatcher', 8),
#  ('Ice Wizzrobe', 8),
#  ('Silver Moblin', 8),
#  ('Water Octorok', 8),
#  ('Black Hinox', 8),
#  ('Igneo Talus Titan', 8),
#  ('Farosh', 7),
#  ('Kapson', 7),
#  ('Naydra', 7),
#  ('Ardin', 7),
#  ('Rotana', 7),
#  ('Canolo', 7),
#  ('Laruta', 7),
#  ('Rivan', 7),
#  ('Amira', 7),
#  ('Nack', 7),
#  ('Reede', 7),
#  ('Darton', 7),
#  ('Shibo', 7),
#  ('Blue-Maned Lynel', 7),
#  ('Cursed Moblin', 7),
#  ('Fire Keese', 7),
#  ('Ice Chuchu', 7),
#  ('Keese', 7),
#  ('Meteo Wizzrobe', 7),
#  ('Silver Lynel', 7),
#  ('Blue Hinox', 7),
#  ('Dinraal', 6),
#  ('Pelison', 6),
#  ('Dmitri', 6),
#  ('Jana', 6),
#  ('Tenne', 6),
#  ('Dai', 6),
#  ('Ashe', 6),
#  ('Barta', 6),
#  ('Patricia', 6),
#  ('Buliara', 6),
#  ('Dalia', 6),
#  ('Kalani', 6),
#  ('Amali', 6),
#  ('Kaneli', 6),
#  ('Dento', 6),
#  ('Finley', 6),
#  ('Kodah', 6),
#  ('Perda', 6),
#  ('Aster', 6),
#  ('Sayge', 6),
#  ('Seldon', 6),
#  ('Symin', 6),
#  ('Tokk', 6),
#  ('Armes', 6),
#  ('Cotera', 6),
#  ('Cado', 6),
#  ('Lasli', 6),
#  ('Olkin', 6),
#  ('Black Moblin', 6),
#  ('Blue Moblin', 6),
#  ('Chuchu', 6),
#  ('Decayed Guardian', 6),
#  ('Electric Wizzrobe', 6),
#  ('Fire Chuchu', 6),
#  ('Forest Octorok', 6),
#  ('Guardian Scout II', 6),
#  ('Ice Keese', 6),
#  ('Rock Octorok', 6),
#  ('Sentry', 6),
#  ('Sky Octorok', 6),
#  ('Snow Octorok', 6),
#  ('Stone Pebblit', 6),
#  ('Treasure Octorok', 6),
#  ('White-Maned Lynel', 6),
#  ('Yiga Blademaster', 6),
#  ('Stalnox', 6),
#  ('Molduking', 6),
#  ('Master Kohga', 6),
#  ('Monk Maz Koshia', 6),
#  ('Dark Beast Ganon', 6),
#  ('Chabi', 5),
#  ('Epona', 5),
#  ('Kenyo', 5),
#  ('Pikango', 5),
#  ('Rhondson', 5),
#  ('Kah Mael', 5),
#  ("Ke'nai Shakah", 5),
#  ('Tutsuwa Nima', 5),
#  ('Ze Kasho', 5),
#  ('Ritaag Zumo', 5),
#  ("Tu Ka'loh", 5),
#  ('Katosa Aug', 5),
#  ('Zuna Kai', 5),
#  ('Etsu Korima', 5),
#  ('Rohta Chigah', 5),
#  ('Ruvo Korbah', 5),
#  ('Yowaka Ita', 5),
#  ('Dah Kaso', 5),
#  ('Katah Chuki', 5),
#  ('Namika Ozz', 5),
#  ('Noya Neha', 5),
#  ("Saas Ko'sah", 5),
#  ("Maag No'rah", 5),
#  ('Mijah Rokee', 5),
#  ('Shira Gomar', 5),
#  ('Gorae Torr', 5),
#  ('Aji', 5),
#  ('Daag Chokah', 5),
#  ('Ketoh Wawai', 5),
#  ('Kuhn Sidajj', 5),
#  ('Maag Halan', 5),
#  ('Pumaag Nitae', 5),
#  ('Shae Katha', 5),
#  ('Shoqa Tatone', 5),
#  ('Anche', 5),
#  ('Benja', 5),
#  ('Dila Maag', 5),
#  ('Keive Tala', 5),
#  ("Korsh O'hu", 5),
#  ('Misae Suma', 5),
#  ('Raqa Zunzo', 5),
#  ('Takama Shiri', 5),
#  ('Tho Kayu', 5),
#  ('Babi', 5),
#  ('Danda', 5),
#  ('Dina', 5),
#  ('Leena', 5),
#  ('Liana', 5),
#  ('Makure', 5),
#  ('Malena', 5),
#  ('Pyra', 5),
#  ('Risa', 5),
#  ('Spera', 5),
#  ('Sumati', 5),
#  ('Teake', 5),
#  ('Yaido', 5),
#  ('Keeha Yoog', 5),
#  ('Kema Kosassa', 5),
#  ('Kihiro Moh', 5),
#  ('Sasa Kai', 5),
#  ('Sesami', 5),
#  ('Suma Sahma', 5),
#  ('Goma Asaagh', 5),
#  ('Hia Miu', 5),
#  ('Kiah Toza', 5),
#  ('Mozo Shenno', 5),
#  ('Noe Rajee', 5),
#  ('Qaza Tokki', 5),
#  ('To Quomo', 5),
#  ('Lanno Kooh', 5),
#  ('Rona Kachta', 5),
#  ("Tena Ko'sah", 5),
#  ('Saki', 5),
#  ('Gruve', 5),
#  ('Ledo', 5),
#  ('Tona', 5),
#  ('Dagah Keek', 5),
#  ('Soh Kofi', 5),
#  ('Fronk', 5),
#  ('Keye', 5),
#  ('Shai Yota', 5),
#  ("Jitan Sa'mi", 5),
#  ("Tahno O'ah", 5),
#  ('Muwo Jeem', 5),
#  ('Tawa Jinn', 5),
#  ('Clavia', 5),
#  ('Horned Statue', 5),
#  ('Koyin', 5),
#  ('Medda', 5),
#  ('Narah', 5),
#  ('Sefaro', 5),
#  ('Chaas Qeta', 5),
#  ('Korgu Chideh', 5),
#  ('Bugut', 5),
#  ('Domidak', 5),
#  ('Prissen', 5),
#  ('Qukah Nata', 5),
#  ('Rensa', 5),
#  ('Lakna Rokee', 5),
#  ('Ollie', 5),
#  ('Cursed Bokoblin', 5),
#  ('Electric Chuchu', 5),
#  ('Golden Bokoblin', 5),
#  ('Guardian Scout III', 5),
#  ('Igneo Pebblit', 5),
#  ('Silver Bokoblin', 5),
#  ('Stone Talus (Rare)', 5),
#  ('Molduga', 5),
#  ('Baddek', 4),
#  ('Beedle', 4),
#  ('Dabi', 4),
#  ('Fyson', 4),
#  ('Meghyn', 4),
#  ('Mei', 4),
#  ('Nat', 4),
#  ('Savelle', 4),
#  ('Spoone', 4),
#  ('Gleema', 4),
#  ('Kaifa', 4),
#  ('Myti', 4),
#  ('Konba', 4),
#  ('Dorill', 4),
#  ('Jengo', 4),
#  ('Akrah', 4),
#  ('Peeks', 4),
#  ('The Great Deku Tree', 4),
#  ('Roscoe', 4),
#  ('Aurie Taamu', 4),
#  ('Estan', 4),
#  ('Furosa', 4),
#  ('Kotta', 4),
#  ('Nali', 4),
#  ('Nellie', 4),
#  ('Ploka', 4),
#  ('Pritana', 4),
#  ('Reeza', 4),
#  ('Rima', 4),
#  ('Saula', 4),
#  ('Harry (Breath of the Wild)', 4),
#  ('Mary (Breath of the Wild)', 4),
#  ('Eryck', 4),
#  ('Torfeau', 4),
#  ('Bazz', 4),
#  ('Dunma', 4),
#  ('Laflat', 4),
#  ('Muzu', 4),
#  ('Seggin', 4),
#  ('Quince', 4),
#  ('Satty', 4),
#  ('Ivee', 4),
#  ('Karin', 4),
#  ('Manny (Breath of the Wild)', 4),
#  ('Nebb', 4),
#  ('Pruce', 4),
#  ('Ralera', 4),
#  ('Kinov', 4),
#  ('Anly', 4),
#  ('Brokka', 4),
#  ('Cima', 4),
#  ('Tasseren', 4),
#  ('Claree', 4),
#  ('Rola', 4),
#  ('Frost Pebblit', 4),
#  ('Guardian Scout I', 4),
#  ('Guardian Scout IV', 4),
#  ('Stone Talus (Luminous)', 4),
#  ('Bayge', 3),
#  ('Brigo', 3),
#  ('Chumin', 3),
#  ('Karson', 3),
#  ('Misko', 3),
#  ('Rik', 3),
#  ('Granté', 3),
#  ('Aya', 3),
#  ('Haite', 3),
#  ('Toffa', 3),
#  ('Branli', 3),
#  ('Axyl', 3),
#  ('Boldon', 3),
#  ('Bargoh', 3),
#  ('Fugo', 3),
#  ('Rohan', 3),
#  ('Kula', 3),
#  ('Malanya', 3),
#  ('Padok', 3),
#  ('Calisa', 3),
#  ('Eighth Heroine', 3),
#  ('Seven Heroines', 3),
#  ('Dillie', 3),
#  ('Jora', 3),
#  ('Pokki', 3),
#  ('Strade', 3),
#  ('Tali', 3),
#  ('Tera', 3),
#  ('Bertri', 3),
#  ('Cara', 3),
#  ('Dorrah', 3),
#  ('Frelly', 3),
#  ('Frita', 3),
#  ('Isha', 3),
#  ('Katta', 3),
#  ('Lorn', 3),
#  ('Marta', 3),
#  ('Padda', 3),
#  ('Pasha', 3),
#  ('Maike', 3),
#  ('Robsten', 3),
#  ('Oliff', 3),
#  ('Tulin', 3),
#  ('Monkton', 3),
#  ('Ariane', 3),
#  ('Cree', 3),
#  ('Genli', 3),
#  ('Kaysa', 3),
#  ('Kotts', 3),
#  ('Notts', 3),
#  ('Pondo', 3),
#  ('Cecili', 3),
#  ('Kayden', 3),
#  ('Ami', 3),
#  ('Wabbin', 3),
#  ('Prima', 3),
#  ('Sophie', 3),
#  ('Tamana', 3),
#  ('Teebo', 3),
#  ('Uma', 3),
#  ('Kiana', 3),
#  ('Sagessa', 3),
#  ('Cottla', 3),
#  ('Koko', 3),
#  ('Mellie', 3),
#  ('Cambo', 2),
#  ('Ena', 2),
#  ('Heehl', 2),
#  ('Hestu', 2),
#  ('Kabetta', 2),
#  ('Mina', 2),
#  ('Nazbi', 2),
#  ('Sho', 2),
#  ('Nell', 2),
#  ('Nobo', 2),
#  ('Glendo', 2),
#  ('Gotter', 2),
#  ('Trott', 2),
#  ('Bohrin', 2),
#  ('Breen', 2),
#  ('Drak', 2),
#  ('Grapp', 2),
#  ('Kish', 2),
#  ('Offrak', 2),
#  ('Ozunda', 2),
#  ('Pyle', 2),
#  ('Ramella', 2),
#  ('Slergo', 2),
#  ('Chio', 2),
#  ('Loone', 2),
#  ('Lukan', 2),
#  ('Shabonne', 2),
#  ('Sudrey', 2),
#  ('Bozai', 2),
#  ('Calyban', 2),
#  ('Deltan', 2),
#  ('Essa', 2),
#  ('Fegran', 2),
#  ('Greta', 2),
#  ('Jules', 2),
#  ('Kohm', 2),
#  ('Laine', 2),
#  ('Lashley', 2),
#  ('Lyndae', 2),
#  ('Merina', 2),
#  ('Muava', 2),
#  ('Olu', 2),
#  ('Romah', 2),
#  ('Smaude', 2),
#  ('Emri', 2),
#  ('Ripp', 2),
#  ('Shaillu', 2),
#  ('Flaxel', 2),
#  ('Palme', 2),
#  ('Harlow', 2),
#  ('Geggle', 2),
#  ('Lester', 2),
#  ('Bedoli', 2),
#  ('Huck', 2),
#  ('Verla', 2),
#  ('Cleff', 2),
#  ('Gaddison', 2),
#  ('Jiahto', 2),
#  ('Marot', 2),
#  ('Reagah', 2),
#  ('Agus', 2),
#  ('Garill', 2),
#  ('Joute', 2),
#  ('Spinch (Hylian)', 2),
#  ('Leop', 2),
#  ('Rhodes', 2),
#  ('Senna', 2),
#  ('Thadd', 2),
#  ('Cloyne', 2),
#  ('Kampo', 2),
#  ('Shay', 2),
#  ('Trissa', 2),
#  ('Stone Talus (Junior)', 2),
#  ('Stone Talus (Senior)', 2),
#  ('Dauntless', 1),
#  ('Mils', 1),
#  ('Toren', 1),
#  ('Yammo', 1),
#  ('Zyle', 1),
#  ('Naddon', 1),
#  ('Pitar', 1),
#  ('Lonni', 1),
#  ('Hoz', 1),
#  ('Khini', 1),
#  ('Rudi', 1),
#  ('Aliza', 1),
#  ('Benny', 1),
#  ('Dugby', 1),
#  ('Kairo', 1),
#  ('Mayro', 1),
#  ('Shamae', 1),
#  ('Krane', 1),
#  ('Rogaro', 1),
#  ('Garshon', 1),
#  ('Onya', 1),
#  ('Zumi', 1),
#  ('Damia', 1),
#  ('Maca', 1),
#  ('Natie', 1),
#  ('Pepp', 1),
#  ('Walton', 1),
#  ('Blynne', 1),
#  ('Jini', 1),
#  ('Gartan', 1),
#  ('Konora', 1),
#  ('Kyra', 1),
#  ('Tauma', 1),
#  ('Guy', 1),
#  ('Kachoo', 1),
#  ('Nobiro', 1),
#  ('Maypin', 1),
#  ('Moza', 1),
#  ('Piaffe', 1),
#  ('Pirou', 1),
#  ('Danton', 1),
#  ('Galli', 1),
#  ('Molli', 1),
#  ('Laissa', 1),
#  ('Mazli', 1),
#  ('Misa', 1),
#  ('Izra', 1),
#  ('Yolero', 1),
#  ('Letty', 1),
#  ('Spinch (Horse)', 1),
#  ('Toma', 1),
#  ('Dantz', 1),
#  ('Chessica', 1),
#  ('Numar', 1),
#  ('Rozel', 1),
#  ('Sebasto', 1),
#  ('Mimo', 1),
#  ('Hino', 1)]

# %% [markdown]
# ### add labels to the top3 degree nodes

# %%
label_dic={node:node for node in G.nodes() if node in ['Link','Calamity Ganon','Hylia']}

options_lab = {
    'labels': label_dic,
    'font_size':10,
    'font_color':'w'
}

# %%
plt.figure(figsize=(12,12))

# draw nodes
nx.draw_networkx_nodes(G,positions, **options_node)
# draw edges
nx.draw_networkx_edges(G,positions, **options_edge)

# draw labels
nx.draw_networkx_labels(G,positions,**options_lab)

# cancel axis
plt.axis('off')
plt.show()

# %% [markdown]
# **Do you observe chains of connected nodes?**<br>
# Yes, nodes are connected as chains if they have same atrributes. So the red chain is enemy group, the blue chain is ally group.

# %% [markdown]
# **Do you see any interesting group of nodes (can you guess who's involved)?<br>**

# %% [markdown]
# # Exercise 4: qualitative inspection

# %% [markdown]
# ##  Top 3 in/out-degree nodes

# %% [markdown]
# ### Top 3 in-degree nodes

# %%
sort_by_value(dict(dir_larG.in_degree())) # sort_by_value is defined on 3.3
# Out:
# [('Link', 386),
#  ('Calamity Ganon', 98),
#  ('Hylia', 67),
#  ('Princess Zelda', 26),
#  ('Riju', 23),
#  ('Bokoblin', 21),
#  ('Purah', 17),
#  ('Mipha', 15),
#  ('Sidon', 14),
#  ('Impa', 14),
#  ('Kilton', 13),
#  ('Ashai', 13),
#  ('Lizalfos', 12),
#  ('King Rhoam', 10),
#  ('King Dorephan', 10),
#  ('Electric Lizalfos', 10),
#  ('Fire-Breath Lizalfos', 10),
#  ('Moblin', 10),
#  ('Bludo', 9),
#  ('Golden Lizalfos', 9),
#  ('Ice-Breath Lizalfos', 9),
#  ('Silver Lizalfos', 9),
#  ('Stalizalfos', 9),
#  ('Stalkoblin', 9),
#  ('Stalmoblin', 9),
#  ('Stone Talus', 9),
#  ('Hudson', 8),
#  ('Kass', 8),
#  ('Revali', 8),
#  ('Robbie', 8),
#  ('Black Lizalfos', 8),
#  ('Blue Bokoblin', 8),
#  ('Blue Lizalfos', 8),
#  ('Lynel', 8),
#  ('Bolson', 7),
#  ('Daruk', 7),
#  ('Urbosa', 7),
#  ('Old Man', 7),
#  ('Yunobo', 7),
#  ('Vilia', 7),
#  ('Black Bokoblin', 7),
#  ('Cursed Lizalfos', 7),
#  ('Guardian Stalker', 7),
#  ('Hinox', 7),
#  ('Windblight Ganon', 7),
#  ('Fireblight Ganon', 7),
#  ('Thunderblight Ganon', 7),
#  ('Waterblight Ganon', 7),
#  ('Dorian', 6),
#  ('Electric Keese', 6),
#  ('Fire Keese', 6),
#  ('Ice Chuchu', 6),
#  ('Igneo Talus', 6),
#  ('Farosh', 5),
#  ('Naydra', 5),
#  ('Dmitri', 5),
#  ('Pearle', 5),
#  ('Rotana', 5),
#  ('Teba', 5),
#  ('Rivan', 5),
#  ('Perda', 5),
#  ('Amira', 5),
#  ('Azu', 5),
#  ('Nikki', 5),
#  ('Sayge', 5),
#  ('Olkin', 5),
#  ('Paya', 5),
#  ('Black Moblin', 5),
#  ('Blizzrobe', 5),
#  ('Blue-Maned Lynel', 5),
#  ('Blue Moblin', 5),
#  ('Cursed Moblin', 5),
#  ('Electric Chuchu', 5),
#  ('Fire Chuchu', 5),
#  ('Fire Wizzrobe', 5),
#  ('Golden Bokoblin', 5),
#  ('Golden Lynel', 5),
#  ('Golden Moblin', 5),
#  ('Guardian Skywatcher', 5),
#  ('Guardian Turret', 5),
#  ('Ice Keese', 5),
#  ('Keese', 5),
#  ('Sentry', 5),
#  ('Silver Bokoblin', 5),
#  ('Silver Lynel', 5),
#  ('Silver Moblin', 5),
#  ('Sky Octorok', 5),
#  ('Thunder Wizzrobe', 5),
#  ('Water Octorok', 5),
#  ('White-Maned Lynel', 5),
#  ('Yiga Footsoldier', 5),
#  ('Frost Talus', 5),
#  ('Dinraal', 4),
#  ('Epona', 4),
#  ('Rhondson', 4),
#  ('Gleema', 4),
#  ('Jana', 4),
#  ('Kaifa', 4),
#  ('Jerrin', 4),
#  ('Barta', 4),
#  ('Patricia', 4),
#  ('Buliara', 4),
#  ('Dalia', 4),
#  ('Kalani', 4),
#  ('Makure', 4),
#  ('Teake', 4),
#  ('Yaido', 4),
#  ('Kaneli', 4),
#  ('Dento', 4),
#  ('Trello', 4),
#  ('Tumbo', 4),
#  ('Karin', 4),
#  ('Nack', 4),
#  ('Reede', 4),
#  ('Cotera', 4),
#  ('Darton', 4),
#  ('Shibo', 4),
#  ('Nanna', 4),
#  ('Steen', 4),
#  ('Chuchu', 4),
#  ('Cursed Bokoblin', 4),
#  ('Decayed Guardian', 4),
#  ('Forest Octorok', 4),
#  ('Guardian Scout II', 4),
#  ('Ice Wizzrobe', 4),
#  ('Igneo Pebblit', 4),
#  ('Meteo Wizzrobe', 4),
#  ('Rock Octorok', 4),
#  ('Snow Octorok', 4),
#  ('Stone Pebblit', 4),
#  ('Treasure Octorok', 4),
#  ('Stalnox', 4),
#  ('Igneo Talus Titan', 4),
#  ('Molduking', 4),
#  ('Master Kohga', 4),
#  ('Dabi', 3),
#  ('Kenyo', 3),
#  ('Mei', 3),
#  ('Pelison', 3),
#  ('Axyl', 3),
#  ('Dorill', 3),
#  ('Fugo', 3),
#  ('Benja', 3),
#  ('Tali', 3),
#  ('Danda', 3),
#  ('Dina', 3),
#  ('Kotta', 3),
#  ('Liana', 3),
#  ('Pyra', 3),
#  ('Saula', 3),
#  ('Spera', 3),
#  ('Sumati', 3),
#  ('Cree', 3),
#  ('Genli', 3),
#  ('Kaysa', 3),
#  ('Kotts', 3),
#  ('Notts', 3),
#  ('Harth', 3),
#  ('Tula', 3),
#  ('Dunma', 3),
#  ('Finley', 3),
#  ('Fronk', 3),
#  ('Keye', 3),
#  ('Muzu', 3),
#  ('Teli', 3),
#  ('Clavia', 3),
#  ('Ivee', 3),
#  ('Pruce', 3),
#  ('Sefaro', 3),
#  ('Seldon', 3),
#  ('Symin', 3),
#  ('Domidak', 3),
#  ('Prissen', 3),
#  ('Rensa', 3),
#  ('Tasseren', 3),
#  ('Cado', 3),
#  ('Claree', 3),
#  ('Lasli', 3),
#  ('Electric Wizzrobe', 3),
#  ('Frost Pebblit', 3),
#  ('Guardian Scout I', 3),
#  ('Guardian Scout III', 3),
#  ('Guardian Scout IV', 3),
#  ('Yiga Blademaster', 3),
#  ('Black Hinox', 3),
#  ('Molduga', 3),
#  ('Monk Maz Koshia', 3),
#  ('Dark Beast Ganon', 3),
#  ('Bayge', 2),
#  ('Beedle', 2),
#  ('Ena', 2),
#  ('Greyson', 2),
#  ('Heehl', 2),
#  ('Kabetta', 2),
#  ('Karson', 2),
#  ('Meghyn', 2),
#  ('Misko', 2),
#  ('Nat', 2),
#  ('Nazbi', 2),
#  ('Savelle', 2),
#  ('Sho', 2),
#  ('Haite', 2),
#  ('Myti', 2),
#  ('Trott', 2),
#  ('Konba', 2),
#  ('Ashe', 2),
#  ('Bohrin', 2),
#  ('Boldon', 2),
#  ('Offrak', 2),
#  ('Aji', 2),
#  ('Rohan', 2),
#  ('Slergo', 2),
#  ('The Great Deku Tree', 2),
#  ('Malanya', 2),
#  ('Roscoe', 2),
#  ('Seven Heroines', 2),
#  ('Anche', 2),
#  ('Pokki', 2),
#  ('Strade', 2),
#  ('Tera', 2),
#  ('Ardin', 2),
#  ('Estan', 2),
#  ('Frelly', 2),
#  ('Frita', 2),
#  ('Furosa', 2),
#  ('Isha', 2),
#  ('Leena', 2),
#  ('Lorn', 2),
#  ('Lyndae', 2),
#  ('Malena', 2),
#  ('Nellie', 2),
#  ('Pasha', 2),
#  ('Ploka', 2),
#  ('Risa', 2),
#  ('Traysi', 2),
#  ('Flaxel', 2),
#  ('Oliff', 2),
#  ('Palme', 2),
#  ('Sesami', 2),
#  ('Tulin', 2),
#  ('Harry (Breath of the Wild)', 2),
#  ('Mary (Breath of the Wild)', 2),
#  ('Monkton', 2),
#  ('Geggle', 2),
#  ('Kheel', 2),
#  ('Amali', 2),
#  ('Saki', 2),
#  ('Verla', 2),
#  ('Tona', 2),
#  ('Bazz', 2),
#  ('Gaddison', 2),
#  ('Kayden', 2),
#  ('Kodah', 2),
#  ('Quince', 2),
#  ('Satty', 2),
#  ('Spinch (Hylian)', 2),
#  ('Wabbin', 2),
#  ('Aster', 2),
#  ('Horned Statue', 2),
#  ('Koyin', 2),
#  ('Manny (Breath of the Wild)', 2),
#  ('Medda', 2),
#  ('Narah', 2),
#  ('Nebb', 2),
#  ('Ralera', 2),
#  ('Senna', 2),
#  ('Sophie', 2),
#  ('Tokk', 2),
#  ('Armes', 2),
#  ('Kiana', 2),
#  ('Kinov', 2),
#  ('Brokka', 2),
#  ('Bugut', 2),
#  ('Kampo', 2),
#  ('Shay', 2),
#  ('Cottla', 2),
#  ('Koko', 2),
#  ('Mellie', 2),
#  ('Rola', 2),
#  ('Stone Talus (Junior)', 2),
#  ('Stone Talus (Senior)', 2),
#  ('Stone Talus (Luminous)', 2),
#  ('Stone Talus (Rare)', 2),
#  ('Blue Hinox', 2),
#  ('Banji', 1),
#  ('Chork', 1),
#  ('Fyson', 1),
#  ('Hestu', 1),
#  ('Kapson', 1),
#  ('Mils', 1),
#  ('Mina', 1),
#  ('Pikango', 1),
#  ('Rik', 1),
#  ('Spoone', 1),
#  ('Toren', 1),
#  ('Yammo', 1),
#  ('Naddon', 1),
#  ('Pitar', 1),
#  ('Kah Mael', 1),
#  ("Ke'nai Shakah", 1),
#  ('Tutsuwa Nima', 1),
#  ('Ze Kasho', 1),
#  ('Ritaag Zumo', 1),
#  ("Tu Ka'loh", 1),
#  ('Hoz', 1),
#  ('Katosa Aug', 1),
#  ('Khini', 1),
#  ('Rudi', 1),
#  ('Zuna Kai', 1),
#  ('Etsu Korima', 1),
#  ('Rohta Chigah', 1),
#  ('Ruvo Korbah', 1),
#  ('Yowaka Ita', 1),
#  ('Canni', 1),
#  ('Dah Kaso', 1),
#  ('Dai', 1),
#  ('Katah Chuki', 1),
#  ('Namika Ozz', 1),
#  ('Noya Neha', 1),
#  ("Saas Ko'sah", 1),
#  ('Toffa', 1),
#  ('Branli', 1),
#  ("Maag No'rah", 1),
#  ('Mijah Rokee', 1),
#  ('Shira Gomar', 1),
#  ('Breen', 1),
#  ('Dugby', 1),
#  ('Gorae Torr', 1),
#  ('Grapp', 1),
#  ('Jengo', 1),
#  ('Kish', 1),
#  ('Ozunda', 1),
#  ('Shamae', 1),
#  ('Pyle', 1),
#  ('Rogaro', 1),
#  ('Daag Chokah', 1),
#  ('Garshon', 1),
#  ('Ketoh Wawai', 1),
#  ('Kuhn Sidajj', 1),
#  ('Maag Halan', 1),
#  ('Onya', 1),
#  ('Zumi', 1),
#  ('Kula', 1),
#  ('Peeks', 1),
#  ('Padok', 1),
#  ('Pumaag Nitae', 1),
#  ('Shae Katha', 1),
#  ('Shoqa Tatone', 1),
#  ('Calisa', 1),
#  ('Eighth Heroine', 1),
#  ('Dila Maag', 1),
#  ('Dillie', 1),
#  ('Jora', 1),
#  ('Keive Tala', 1),
#  ("Korsh O'hu", 1),
#  ('Misae Suma', 1),
#  ('Raqa Zunzo', 1),
#  ('Shabonne', 1),
#  ('Takama Shiri', 1),
#  ('Tho Kayu', 1),
#  ('Aurie Taamu', 1),
#  ('Babi', 1),
#  ('Bozai', 1),
#  ('Cara', 1),
#  ('Dorrah', 1),
#  ('Greta', 1),
#  ('Jules', 1),
#  ('Katta', 1),
#  ('Kohm', 1),
#  ('Marta', 1),
#  ('Merina', 1),
#  ('Muava', 1),
#  ('Nali', 1),
#  ('Padda', 1),
#  ('Pritana', 1),
#  ('Reeza', 1),
#  ('Romah', 1),
#  ('Smaude', 1),
#  ('Maike', 1),
#  ('Robsten', 1),
#  ('Canolo', 1),
#  ('Keeha Yoog', 1),
#  ('Kema Kosassa', 1),
#  ('Kihiro Moh', 1),
#  ('Sasa Kai', 1),
#  ('Suma Sahma', 1),
#  ('Goma Asaagh', 1),
#  ('Hia Miu', 1),
#  ('Kiah Toza', 1),
#  ('Mozo Shenno', 1),
#  ('Noe Rajee', 1),
#  ('Qaza Tokki', 1),
#  ('To Quomo', 1),
#  ('Danton', 1),
#  ('Galli', 1),
#  ('Lanno Kooh', 1),
#  ('Lester', 1),
#  ('Molli', 1),
#  ('Pondo', 1),
#  ('Rona Kachta', 1),
#  ("Tena Ko'sah", 1),
#  ('Laissa', 1),
#  ('Misa', 1),
#  ('Gruve', 1),
#  ('Ledo', 1),
#  ('Eryck', 1),
#  ('Dagah Keek', 1),
#  ('Soh Kofi', 1),
#  ('Torfeau', 1),
#  ('Cleff', 1),
#  ('Laruta', 1),
#  ('Marot', 1),
#  ('Seggin', 1),
#  ('Shai Yota', 1),
#  ('Izra', 1),
#  ('Yolero', 1),
#  ("Jitan Sa'mi", 1),
#  ("Tahno O'ah", 1),
#  ('Agus', 1),
#  ('Joute', 1),
#  ('Letty', 1),
#  ('Toma', 1),
#  ('Muwo Jeem', 1),
#  ('Tawa Jinn', 1),
#  ('Dantz', 1),
#  ('Prima', 1),
#  ('Rhodes', 1),
#  ('Tamana', 1),
#  ('Teebo', 1),
#  ('Uma', 1),
#  ('Cloyne', 1),
#  ('Numar', 1),
#  ('Rozel', 1),
#  ('Sebasto', 1),
#  ('Chaas Qeta', 1),
#  ('Korgu Chideh', 1),
#  ('Anly', 1),
#  ('Cima', 1),
#  ('Qukah Nata', 1),
#  ('Lakna Rokee', 1),
#  ('Ollie', 1),
#  ('Trissa', 1),
#  ('Baddek', 0),
#  ('Brigo', 0),
#  ('Cambo', 0),
#  ('Chabi', 0),
#  ('Chumin', 0),
#  ('Dauntless', 0),
#  ('Zyle', 0),
#  ('Lonni', 0),
#  ('Nell', 0),
#  ('Tenne', 0),
#  ('Granté', 0),
#  ('Aya', 0),
#  ('Nobo', 0),
#  ('Glendo', 0),
#  ('Aliza', 0),
#  ('Benny', 0),
#  ('Gotter', 0),
#  ('Drak', 0),
#  ('Kairo', 0),
#  ('Mayro', 0),
#  ('Bargoh', 0),
#  ('Krane', 0),
#  ('Ramella', 0),
#  ('Akrah', 0),
#  ('Chio', 0),
#  ('Damia', 0),
#  ('Maca', 0),
#  ('Natie', 0),
#  ('Pepp', 0),
#  ('Walton', 0),
#  ('Blynne', 0),
#  ('Jini', 0),
#  ('Loone', 0),
#  ('Gartan', 0),
#  ('Lukan', 0),
#  ('Konora', 0),
#  ('Kyra', 0),
#  ('Sudrey', 0),
#  ('Bertri', 0),
#  ('Calyban', 0),
#  ('Deltan', 0),
#  ('Essa', 0),
#  ('Fegran', 0),
#  ('Laine', 0),
#  ('Lashley', 0),
#  ('Olu', 0),
#  ('Rima', 0),
#  ('Tauma', 0),
#  ('Emri', 0),
#  ('Guy', 0),
#  ('Kachoo', 0),
#  ('Nobiro', 0),
#  ('Ripp', 0),
#  ('Shaillu', 0),
#  ('Maypin', 0),
#  ('Moza', 0),
#  ('Piaffe', 0),
#  ('Pirou', 0),
#  ('Harlow', 0),
#  ('Ariane', 0),
#  ('Bedoli', 0),
#  ('Cecili', 0),
#  ('Huck', 0),
#  ('Mazli', 0),
#  ('Jiahto', 0),
#  ('Laflat', 0),
#  ('Reagah', 0),
#  ('Ami', 0),
#  ('Celessa', 0),
#  ('Garill', 0),
#  ('Spinch (Horse)', 0),
#  ('Leop', 0),
#  ('Thadd', 0),
#  ('Chessica', 0),
#  ('Mimo', 0),
#  ('Hino', 0),
#  ('Sagessa', 0)]

# %% [markdown]
# The top three in-degree nodes are **'Link','Calamity Ganon' and 'Hylia'**
# https://zelda.fandom.com/wiki/Link#Breath_of_the_Wild
# https://zelda.fandom.com/wiki/Calamity_Ganon#Breath_of_the_Wild
# https://zelda.fandom.com/wiki/Hylia#Breath_of_the_Wild

# %% [markdown]
# ###  the relation between these 3 characters and his/her network neighbours?

# %%
df.query('Name=="Link" | Name=="Calamity Ganon" | Name=="Hylia"')
# Out:
#                Name  Role    Race  Gender
# 26            Hylia  Ally  Hylian  Female
# 35             Link  Ally  Hylian    Male
# 654  Calamity Ganon  Boss  Gerudo    Male

# %%
HL_neig = [j for j in dir_larG.neighbors('Hylia')]
CG_neig = [j for j in dir_larG.neighbors('Calamity Ganon')]
Link_neig = [j for j in dir_larG.neighbors('Link')]
print('Link\'s neighbors',Link_neig)
print('Calamity Ganon\'s neighbors',CG_neig)
print('Hylia\'s neighbors',HL_neig)
# Out:
# Link's neighbors ['Princess Zelda', 'Epona', 'Impa', 'Hylia', 'Old Man', 'Calamity Ganon', 'King Rhoam', 'Kass', 'Paya', 'Link']
# Calamity Ganon's neighbors ['Dark Beast Ganon', 'Fireblight Ganon', 'Thunderblight Ganon', 'Waterblight Ganon', 'Windblight Ganon', 'Calamity Ganon', 'Princess Zelda', 'Link']
# Hylia's neighbors ['Princess Zelda', 'Impa']

# %% [markdown]
# Link and Hylia are both Hylian and they're allies. All of three connect to Princess Zelda.

# %% [markdown]
# ### Top 3 out-degree node

# %%
sort_by_value(dict(dir_larG.out_degree()))
# Out:
# [('Traysi', 14),
#  ('Lizalfos', 13),
#  ('Stalizalfos', 12),
#  ('Moblin', 11),
#  ('Silver Lizalfos', 11),
#  ('Stone Talus', 11),
#  ('Daruk', 10),
#  ('Link', 10),
#  ('Impa', 10),
#  ('Bokoblin', 10),
#  ('Lynel', 10),
#  ('Stalmoblin', 10),
#  ('Banji', 9),
#  ('Kass', 9),
#  ('Urbosa', 9),
#  ('Purah', 9),
#  ('Dorian', 9),
#  ('Blue Lizalfos', 9),
#  ('Cursed Lizalfos', 9),
#  ('Electric Lizalfos', 9),
#  ('Fire-Breath Lizalfos', 9),
#  ('Fire Wizzrobe', 9),
#  ('Ice-Breath Lizalfos', 9),
#  ('Yiga Footsoldier', 9),
#  ('Chork', 8),
#  ('Greyson', 8),
#  ('Mipha', 8),
#  ('Princess Zelda', 8),
#  ('Teba', 8),
#  ('Kheel', 8),
#  ('Celessa', 8),
#  ('Azu', 8),
#  ('Nanna', 8),
#  ('Black Lizalfos', 8),
#  ('Blue Bokoblin', 8),
#  ('Golden Lizalfos', 8),
#  ('Golden Moblin', 8),
#  ('Stalkoblin', 8),
#  ('Igneo Talus', 8),
#  ('Fireblight Ganon', 8),
#  ('Calamity Ganon', 8),
#  ('Revali', 7),
#  ('Canni', 7),
#  ('Pearle', 7),
#  ('Canolo', 7),
#  ('Harth', 7),
#  ('Laruta', 7),
#  ('Tumbo', 7),
#  ('Nikki', 7),
#  ('Paya', 7),
#  ('Black Bokoblin', 7),
#  ('Golden Lynel', 7),
#  ('Guardian Stalker', 7),
#  ('Guardian Skywatcher', 7),
#  ('Guardian Turret', 7),
#  ('Ice Wizzrobe', 7),
#  ('Silver Moblin', 7),
#  ('Thunder Wizzrobe', 7),
#  ('Water Octorok', 7),
#  ('Frost Talus', 7),
#  ('Hinox', 7),
#  ('Blue Hinox', 7),
#  ('Black Hinox', 7),
#  ('Igneo Talus Titan', 7),
#  ('Windblight Ganon', 7),
#  ('Thunderblight Ganon', 7),
#  ('Kapson', 6),
#  ('Tenne', 6),
#  ('Jerrin', 6),
#  ('Robbie', 6),
#  ('King Rhoam', 6),
#  ('Yunobo', 6),
#  ('Barta', 6),
#  ('Ardin', 6),
#  ('Kalani', 6),
#  ('Amali', 6),
#  ('Sidon', 6),
#  ('King Dorephan', 6),
#  ('Kodah', 6),
#  ('Rivan', 6),
#  ('Trello', 6),
#  ('Perda', 6),
#  ('Teli', 6),
#  ('Amira', 6),
#  ('Blizzrobe', 6),
#  ('Blue-Maned Lynel', 6),
#  ('Cursed Moblin', 6),
#  ('Electric Wizzrobe', 6),
#  ('Forest Octorok', 6),
#  ('Meteo Wizzrobe', 6),
#  ('Rock Octorok', 6),
#  ('Snow Octorok', 6),
#  ('Treasure Octorok', 6),
#  ('Waterblight Ganon', 6),
#  ('Bolson', 5),
#  ('Chabi', 5),
#  ('Pelison', 5),
#  ('Jana', 5),
#  ('Dai', 5),
#  ('Ashe', 5),
#  ('Riju', 5),
#  ('Ashai', 5),
#  ('Babi', 5),
#  ('Dalia', 5),
#  ('Leena', 5),
#  ('Liana', 5),
#  ('Makure', 5),
#  ('Pyra', 5),
#  ('Risa', 5),
#  ('Sumati', 5),
#  ('Yaido', 5),
#  ('Sesami', 5),
#  ('Saki', 5),
#  ('Tona', 5),
#  ('Tula', 5),
#  ('Finley', 5),
#  ('Fronk', 5),
#  ('Keye', 5),
#  ('Aster', 5),
#  ('Narah', 5),
#  ('Reede', 5),
#  ('Sefaro', 5),
#  ('Tokk', 5),
#  ('Armes', 5),
#  ('Cotera', 5),
#  ('Darton', 5),
#  ('Rensa', 5),
#  ('Shibo', 5),
#  ('Cado', 5),
#  ('Lasli', 5),
#  ('Steen', 5),
#  ('Black Moblin', 5),
#  ('Blue Moblin', 5),
#  ('Chuchu', 5),
#  ('Cursed Bokoblin', 5),
#  ('Decayed Guardian', 5),
#  ('Electric Keese', 5),
#  ('Golden Bokoblin', 5),
#  ('Guardian Scout II', 5),
#  ('Guardian Scout III', 5),
#  ('Keese', 5),
#  ('Silver Bokoblin', 5),
#  ('Silver Lynel', 5),
#  ('Stone Pebblit', 5),
#  ('Stone Talus (Rare)', 5),
#  ('Molduking', 5),
#  ('Baddek', 4),
#  ('Dinraal', 4),
#  ('Farosh', 4),
#  ('Hudson', 4),
#  ('Kilton', 4),
#  ('Mei', 4),
#  ('Naydra', 4),
#  ('Pikango', 4),
#  ('Dmitri', 4),
#  ('Kah Mael', 4),
#  ("Ke'nai Shakah", 4),
#  ('Tutsuwa Nima', 4),
#  ('Ze Kasho', 4),
#  ('Ritaag Zumo', 4),
#  ("Tu Ka'loh", 4),
#  ('Katosa Aug', 4),
#  ('Zuna Kai', 4),
#  ('Etsu Korima', 4),
#  ('Old Man', 4),
#  ('Rohta Chigah', 4),
#  ('Ruvo Korbah', 4),
#  ('Yowaka Ita', 4),
#  ('Dah Kaso', 4),
#  ('Katah Chuki', 4),
#  ('Namika Ozz', 4),
#  ('Noya Neha', 4),
#  ("Saas Ko'sah", 4),
#  ("Maag No'rah", 4),
#  ('Mijah Rokee', 4),
#  ('Shira Gomar', 4),
#  ('Gorae Torr', 4),
#  ('Jengo', 4),
#  ('Aji', 4),
#  ('Akrah', 4),
#  ('Daag Chokah', 4),
#  ('Ketoh Wawai', 4),
#  ('Kuhn Sidajj', 4),
#  ('Maag Halan', 4),
#  ('Pumaag Nitae', 4),
#  ('Shae Katha', 4),
#  ('Shoqa Tatone', 4),
#  ('Anche', 4),
#  ('Benja', 4),
#  ('Dila Maag', 4),
#  ('Keive Tala', 4),
#  ("Korsh O'hu", 4),
#  ('Misae Suma', 4),
#  ('Patricia', 4),
#  ('Raqa Zunzo', 4),
#  ('Takama Shiri', 4),
#  ('Tho Kayu', 4),
#  ('Buliara', 4),
#  ('Danda', 4),
#  ('Furosa', 4),
#  ('Nali', 4),
#  ('Nellie', 4),
#  ('Ploka', 4),
#  ('Pritana', 4),
#  ('Reeza', 4),
#  ('Rima', 4),
#  ('Rotana', 4),
#  ('Vilia', 4),
#  ('Keeha Yoog', 4),
#  ('Kema Kosassa', 4),
#  ('Kihiro Moh', 4),
#  ('Sasa Kai', 4),
#  ('Suma Sahma', 4),
#  ('Goma Asaagh', 4),
#  ('Hia Miu', 4),
#  ('Kiah Toza', 4),
#  ('Mozo Shenno', 4),
#  ('Noe Rajee', 4),
#  ('Qaza Tokki', 4),
#  ('To Quomo', 4),
#  ('Lanno Kooh', 4),
#  ('Rona Kachta', 4),
#  ("Tena Ko'sah", 4),
#  ('Gruve', 4),
#  ('Ledo', 4),
#  ('Dagah Keek', 4),
#  ('Soh Kofi', 4),
#  ('Bazz', 4),
#  ('Laflat', 4),
#  ('Muzu', 4),
#  ('Shai Yota', 4),
#  ("Jitan Sa'mi", 4),
#  ("Tahno O'ah", 4),
#  ('Muwo Jeem', 4),
#  ('Tawa Jinn', 4),
#  ('Clavia', 4),
#  ('Horned Statue', 4),
#  ('Ivee', 4),
#  ('Koyin', 4),
#  ('Medda', 4),
#  ('Nack', 4),
#  ('Nebb', 4),
#  ('Pruce', 4),
#  ('Ralera', 4),
#  ('Seldon', 4),
#  ('Symin', 4),
#  ('Chaas Qeta', 4),
#  ('Korgu Chideh', 4),
#  ('Anly', 4),
#  ('Bugut', 4),
#  ('Cima', 4),
#  ('Domidak', 4),
#  ('Prissen', 4),
#  ('Qukah Nata', 4),
#  ('Lakna Rokee', 4),
#  ('Ollie', 4),
#  ('Fire Chuchu', 4),
#  ('Fire Keese', 4),
#  ('Frost Pebblit', 4),
#  ('Guardian Scout I', 4),
#  ('Guardian Scout IV', 4),
#  ('Ice Chuchu', 4),
#  ('Ice Keese', 4),
#  ('Igneo Pebblit', 4),
#  ('Yiga Blademaster', 4),
#  ('Stone Talus (Luminous)', 4),
#  ('Monk Maz Koshia', 4),
#  ('Dark Beast Ganon', 4),
#  ('Bayge', 3),
#  ('Brigo', 3),
#  ('Chumin', 3),
#  ('Fyson', 3),
#  ('Karson', 3),
#  ('Meghyn', 3),
#  ('Misko', 3),
#  ('Nat', 3),
#  ('Spoone', 3),
#  ('Gleema', 3),
#  ('Kaifa', 3),
#  ('Granté', 3),
#  ('Aya', 3),
#  ('Myti', 3),
#  ('Boldon', 3),
#  ('Bargoh', 3),
#  ('Bludo', 3),
#  ('Fugo', 3),
#  ('Rohan', 3),
#  ('Peeks', 3),
#  ('Eighth Heroine', 3),
#  ('Seven Heroines', 3),
#  ('Dillie', 3),
#  ('Jora', 3),
#  ('Tera', 3),
#  ('Aurie Taamu', 3),
#  ('Bertri', 3),
#  ('Cara', 3),
#  ('Dina', 3),
#  ('Dorrah', 3),
#  ('Estan', 3),
#  ('Kotta', 3),
#  ('Malena', 3),
#  ('Marta', 3),
#  ('Padda', 3),
#  ('Teake', 3),
#  ('Maike', 3),
#  ('Robsten', 3),
#  ('Tulin', 3),
#  ('Harry (Breath of the Wild)', 3),
#  ('Mary (Breath of the Wild)', 3),
#  ('Ariane', 3),
#  ('Kaysa', 3),
#  ('Cecili', 3),
#  ('Eryck', 3),
#  ('Torfeau', 3),
#  ('Dento', 3),
#  ('Dunma', 3),
#  ('Kayden', 3),
#  ('Seggin', 3),
#  ('Ami', 3),
#  ('Quince', 3),
#  ('Satty', 3),
#  ('Sayge', 3),
#  ('Sophie', 3),
#  ('Teebo', 3),
#  ('Kinov', 3),
#  ('Brokka', 3),
#  ('Sagessa', 3),
#  ('Claree', 3),
#  ('Cottla', 3),
#  ('Koko', 3),
#  ('Rola', 3),
#  ('Electric Chuchu', 3),
#  ('Sentry', 3),
#  ('White-Maned Lynel', 3),
#  ('Stalnox', 3),
#  ('Molduga', 3),
#  ('Beedle', 2),
#  ('Cambo', 2),
#  ('Epona', 2),
#  ('Heehl', 2),
#  ('Hylia', 2),
#  ('Kabetta', 2),
#  ('Kenyo', 2),
#  ('Mina', 2),
#  ('Rhondson', 2),
#  ('Rik', 2),
#  ('Savelle', 2),
#  ('Nell', 2),
#  ('Nobo', 2),
#  ('Glendo', 2),
#  ('Gotter', 2),
#  ('Haite', 2),
#  ('Toffa', 2),
#  ('Branli', 2),
#  ('Konba', 2),
#  ('Axyl', 2),
#  ('Dorill', 2),
#  ('Drak', 2),
#  ('Grapp', 2),
#  ('Pyle', 2),
#  ('Ramella', 2),
#  ('Slergo', 2),
#  ('Chio', 2),
#  ('Kula', 2),
#  ('The Great Deku Tree', 2),
#  ('Loone', 2),
#  ('Padok', 2),
#  ('Roscoe', 2),
#  ('Calisa', 2),
#  ('Lukan', 2),
#  ('Pokki', 2),
#  ('Shabonne', 2),
#  ('Strade', 2),
#  ('Sudrey', 2),
#  ('Tali', 2),
#  ('Calyban', 2),
#  ('Deltan', 2),
#  ('Essa', 2),
#  ('Fegran', 2),
#  ('Frelly', 2),
#  ('Isha', 2),
#  ('Katta', 2),
#  ('Kohm', 2),
#  ('Laine', 2),
#  ('Lashley', 2),
#  ('Lorn', 2),
#  ('Merina', 2),
#  ('Olu', 2),
#  ('Pasha', 2),
#  ('Saula', 2),
#  ('Spera', 2),
#  ('Emri', 2),
#  ('Ripp', 2),
#  ('Shaillu', 2),
#  ('Oliff', 2),
#  ('Harlow', 2),
#  ('Pondo', 2),
#  ('Bedoli', 2),
#  ('Huck', 2),
#  ('Kaneli', 2),
#  ('Cleff', 2),
#  ('Gaddison', 2),
#  ('Jiahto', 2),
#  ('Marot', 2),
#  ('Reagah', 2),
#  ('Garill', 2),
#  ('Wabbin', 2),
#  ('Karin', 2),
#  ('Leop', 2),
#  ('Manny (Breath of the Wild)', 2),
#  ('Prima', 2),
#  ('Rhodes', 2),
#  ('Senna', 2),
#  ('Tamana', 2),
#  ('Thadd', 2),
#  ('Uma', 2),
#  ('Cloyne', 2),
#  ('Kiana', 2),
#  ('Tasseren', 2),
#  ('Mellie', 2),
#  ('Olkin', 2),
#  ('Trissa', 2),
#  ('Stone Talus (Junior)', 2),
#  ('Stone Talus (Senior)', 2),
#  ('Master Kohga', 2),
#  ('Dabi', 1),
#  ('Dauntless', 1),
#  ('Hestu', 1),
#  ('Mils', 1),
#  ('Toren', 1),
#  ('Zyle', 1),
#  ('Naddon', 1),
#  ('Lonni', 1),
#  ('Hoz', 1),
#  ('Aliza', 1),
#  ('Benny', 1),
#  ('Breen', 1),
#  ('Dugby', 1),
#  ('Kairo', 1),
#  ('Kish', 1),
#  ('Mayro', 1),
#  ('Offrak', 1),
#  ('Ozunda', 1),
#  ('Shamae', 1),
#  ('Krane', 1),
#  ('Rogaro', 1),
#  ('Damia', 1),
#  ('Maca', 1),
#  ('Natie', 1),
#  ('Pepp', 1),
#  ('Walton', 1),
#  ('Blynne', 1),
#  ('Jini', 1),
#  ('Malanya', 1),
#  ('Gartan', 1),
#  ('Konora', 1),
#  ('Kyra', 1),
#  ('Bozai', 1),
#  ('Frita', 1),
#  ('Greta', 1),
#  ('Jules', 1),
#  ('Lyndae', 1),
#  ('Muava', 1),
#  ('Romah', 1),
#  ('Smaude', 1),
#  ('Tauma', 1),
#  ('Guy', 1),
#  ('Kachoo', 1),
#  ('Nobiro', 1),
#  ('Maypin', 1),
#  ('Moza', 1),
#  ('Piaffe', 1),
#  ('Pirou', 1),
#  ('Monkton', 1),
#  ('Lester', 1),
#  ('Molli', 1),
#  ('Mazli', 1),
#  ('Agus', 1),
#  ('Joute', 1),
#  ('Spinch (Horse)', 1),
#  ('Chessica', 1),
#  ('Rozel', 1),
#  ('Mimo', 1),
#  ('Hino', 1),
#  ('Sky Octorok', 1),
#  ('Ena', 0),
#  ('Nazbi', 0),
#  ('Sho', 0),
#  ('Yammo', 0),
#  ('Pitar', 0),
#  ('Khini', 0),
#  ('Rudi', 0),
#  ('Trott', 0),
#  ('Bohrin', 0),
#  ('Garshon', 0),
#  ('Onya', 0),
#  ('Zumi', 0),
#  ('Flaxel', 0),
#  ('Palme', 0),
#  ('Danton', 0),
#  ('Cree', 0),
#  ('Galli', 0),
#  ('Geggle', 0),
#  ('Genli', 0),
#  ('Kotts', 0),
#  ('Notts', 0),
#  ('Laissa', 0),
#  ('Misa', 0),
#  ('Verla', 0),
#  ('Izra', 0),
#  ('Yolero', 0),
#  ('Letty', 0),
#  ('Spinch (Hylian)', 0),
#  ('Toma', 0),
#  ('Dantz', 0),
#  ('Numar', 0),
#  ('Sebasto', 0),
#  ('Kampo', 0),
#  ('Shay', 0)]

# %% [markdown]
# The top three out-degree nodes are **'Traysi','Lizalfos' and 'Stalizalfos'**
# https://zelda.fandom.com/wiki/Traysi#Breath_of_the_Wild
# https://zelda.fandom.com/wiki/Lizalfos#Breath_of_the_Wild
# https://zelda.fandom.com/wiki/Stalizalfos#Breath_of_the_Wild

# %%
df.query('Name=="Traysi" | Name=="Lizalfos" | Name=="Stalizalfos"')
# Out:
#             Name   Role      Race   Gender
# 320       Traysi   Ally    Hylian   Female
# 612     Lizalfos  Enemy  Lizalfos  Unknown
# 624  Stalizalfos  Enemy  Lizalfos  Unknown

# %% [markdown]
# Traysi is one of the most important NPC in BtoW pushing the storyline. Link has a lot of plots with her. That's why she has most in-degrees. And Lizalfos is one of the most important enemies who has many variaties.Stalizalfos is one of them. This is the reason they have second and third most in-degrees.

# %% [markdown]
# ## Are there any nodes with high out-degree and with few incoming connections?

# %% [markdown]
# We can use $ratio_{in-out}=\frac{in-degree-amount}{out-degree-amount}$ to find nodes with great contrary between in-degree and out-degree. The smaller $ratio_{in-out}$ is, the bigger the contrary, which means high out-degree and few incoming connections.

# %%
# save the ratio in a dict
in_out_ratio = {}

# average in_degree and out-degree amount
avg_in_degree = np.mean(list(dict(dir_larG.in_degree).values()))
avg_out_degree = np.mean(list(dict(dir_larG.out_degree).values()))

for i,j in sort_by_value(dict(dir_larG.out_degree())):
    # For high out-degree nodes, I choose those above average out-degree
    if (dir_larG.in_degree[i] != 0) & (j != 0) & (j>avg_out_degree):
        in_out_ratio[i] = dir_larG.in_degree[i]/j
        
# output this dict values from low to high
sorted(in_out_ratio.items(),  key=lambda d: d[1], reverse=False)
# Out:
# [('Banji', 0.1111111111111111),
#  ('Chork', 0.125),
#  ('Traysi', 0.14285714285714285),
#  ('Canni', 0.14285714285714285),
#  ('Canolo', 0.14285714285714285),
#  ('Laruta', 0.14285714285714285),
#  ('Kapson', 0.16666666666666666),
#  ('Dai', 0.2),
#  ('Babi', 0.2),
#  ('Greyson', 0.25),
#  ('Kheel', 0.25),
#  ('Pikango', 0.25),
#  ('Kah Mael', 0.25),
#  ("Ke'nai Shakah", 0.25),
#  ('Tutsuwa Nima', 0.25),
#  ('Ze Kasho', 0.25),
#  ('Ritaag Zumo', 0.25),
#  ("Tu Ka'loh", 0.25),
#  ('Katosa Aug', 0.25),
#  ('Zuna Kai', 0.25),
#  ('Etsu Korima', 0.25),
#  ('Rohta Chigah', 0.25),
#  ('Ruvo Korbah', 0.25),
#  ('Yowaka Ita', 0.25),
#  ('Dah Kaso', 0.25),
#  ('Katah Chuki', 0.25),
#  ('Namika Ozz', 0.25),
#  ('Noya Neha', 0.25),
#  ("Saas Ko'sah", 0.25),
#  ("Maag No'rah", 0.25),
#  ('Mijah Rokee', 0.25),
#  ('Shira Gomar', 0.25),
#  ('Gorae Torr', 0.25),
#  ('Jengo', 0.25),
#  ('Daag Chokah', 0.25),
#  ('Ketoh Wawai', 0.25),
#  ('Kuhn Sidajj', 0.25),
#  ('Maag Halan', 0.25),
#  ('Pumaag Nitae', 0.25),
#  ('Shae Katha', 0.25),
#  ('Shoqa Tatone', 0.25),
#  ('Dila Maag', 0.25),
#  ('Keive Tala', 0.25),
#  ("Korsh O'hu", 0.25),
#  ('Misae Suma', 0.25),
#  ('Raqa Zunzo', 0.25),
#  ('Takama Shiri', 0.25),
#  ('Tho Kayu', 0.25),
#  ('Nali', 0.25),
#  ('Pritana', 0.25),
#  ('Reeza', 0.25),
#  ('Keeha Yoog', 0.25),
#  ('Kema Kosassa', 0.25),
#  ('Kihiro Moh', 0.25),
#  ('Sasa Kai', 0.25),
#  ('Suma Sahma', 0.25),
#  ('Goma Asaagh', 0.25),
#  ('Hia Miu', 0.25),
#  ('Kiah Toza', 0.25),
#  ('Mozo Shenno', 0.25),
#  ('Noe Rajee', 0.25),
#  ('Qaza Tokki', 0.25),
#  ('To Quomo', 0.25),
#  ('Lanno Kooh', 0.25),
#  ('Rona Kachta', 0.25),
#  ("Tena Ko'sah", 0.25),
#  ('Gruve', 0.25),
#  ('Ledo', 0.25),
#  ('Dagah Keek', 0.25),
#  ('Soh Kofi', 0.25),
#  ('Shai Yota', 0.25),
#  ("Jitan Sa'mi", 0.25),
#  ("Tahno O'ah", 0.25),
#  ('Muwo Jeem', 0.25),
#  ('Tawa Jinn', 0.25),
#  ('Chaas Qeta', 0.25),
#  ('Korgu Chideh', 0.25),
#  ('Anly', 0.25),
#  ('Cima', 0.25),
#  ('Qukah Nata', 0.25),
#  ('Lakna Rokee', 0.25),
#  ('Ollie', 0.25),
#  ('Blue Hinox', 0.2857142857142857),
#  ('Ardin', 0.3333333333333333),
#  ('Amali', 0.3333333333333333),
#  ('Kodah', 0.3333333333333333),
#  ('Ashe', 0.4),
#  ('Leena', 0.4),
#  ('Risa', 0.4),
#  ('Sesami', 0.4),
#  ('Saki', 0.4),
#  ('Tona', 0.4),
#  ('Aster', 0.4),
#  ('Narah', 0.4),
#  ('Tokk', 0.4),
#  ('Armes', 0.4),
#  ('Stone Talus (Rare)', 0.4),
#  ('Harth', 0.42857142857142855),
#  ('Black Hinox', 0.42857142857142855),
#  ('Nanna', 0.5),
#  ('Teli', 0.5),
#  ('Electric Wizzrobe', 0.5),
#  ('Aji', 0.5),
#  ('Anche', 0.5),
#  ('Furosa', 0.5),
#  ('Nellie', 0.5),
#  ('Ploka', 0.5),
#  ('Bazz', 0.5),
#  ('Horned Statue', 0.5),
#  ('Koyin', 0.5),
#  ('Medda', 0.5),
#  ('Nebb', 0.5),
#  ('Ralera', 0.5),
#  ('Bugut', 0.5),
#  ('Stone Talus (Luminous)', 0.5),
#  ('Fire Wizzrobe', 0.5555555555555556),
#  ('Yiga Footsoldier', 0.5555555555555556),
#  ('Tumbo', 0.5714285714285714),
#  ('Ice Wizzrobe', 0.5714285714285714),
#  ('Igneo Talus Titan', 0.5714285714285714),
#  ('Pelison', 0.6),
#  ('Liana', 0.6),
#  ('Pyra', 0.6),
#  ('Sumati', 0.6),
#  ('Tula', 0.6),
#  ('Finley', 0.6),
#  ('Fronk', 0.6),
#  ('Keye', 0.6),
#  ('Sefaro', 0.6),
#  ('Rensa', 0.6),
#  ('Cado', 0.6),
#  ('Lasli', 0.6),
#  ('Guardian Scout III', 0.6),
#  ('Teba', 0.625),
#  ('Azu', 0.625),
#  ('Golden Moblin', 0.625),
#  ('Dorian', 0.6666666666666666),
#  ('Jerrin', 0.6666666666666666),
#  ('Barta', 0.6666666666666666),
#  ('Kalani', 0.6666666666666666),
#  ('Trello', 0.6666666666666666),
#  ('Forest Octorok', 0.6666666666666666),
#  ('Meteo Wizzrobe', 0.6666666666666666),
#  ('Rock Octorok', 0.6666666666666666),
#  ('Snow Octorok', 0.6666666666666666),
#  ('Treasure Octorok', 0.6666666666666666),
#  ('Daruk', 0.7),
#  ('Pearle', 0.7142857142857143),
#  ('Nikki', 0.7142857142857143),
#  ('Paya', 0.7142857142857143),
#  ('Golden Lynel', 0.7142857142857143),
#  ('Guardian Skywatcher', 0.7142857142857143),
#  ('Guardian Turret', 0.7142857142857143),
#  ('Silver Moblin', 0.7142857142857143),
#  ('Thunder Wizzrobe', 0.7142857142857143),
#  ('Water Octorok', 0.7142857142857143),
#  ('Frost Talus', 0.7142857142857143),
#  ('Stalizalfos', 0.75),
#  ('Igneo Talus', 0.75),
#  ('Mei', 0.75),
#  ('Benja', 0.75),
#  ('Danda', 0.75),
#  ('Muzu', 0.75),
#  ('Clavia', 0.75),
#  ('Ivee', 0.75),
#  ('Pruce', 0.75),
#  ('Seldon', 0.75),
#  ('Symin', 0.75),
#  ('Domidak', 0.75),
#  ('Prissen', 0.75),
#  ('Frost Pebblit', 0.75),
#  ('Guardian Scout I', 0.75),
#  ('Guardian Scout IV', 0.75),
#  ('Yiga Blademaster', 0.75),
#  ('Monk Maz Koshia', 0.75),
#  ('Dark Beast Ganon', 0.75),
#  ('Urbosa', 0.7777777777777778),
#  ('Cursed Lizalfos', 0.7777777777777778),
#  ('Lynel', 0.8),
#  ('Jana', 0.8),
#  ('Dalia', 0.8),
#  ('Makure', 0.8),
#  ('Yaido', 0.8),
#  ('Reede', 0.8),
#  ('Cotera', 0.8),
#  ('Darton', 0.8),
#  ('Shibo', 0.8),
#  ('Steen', 0.8),
#  ('Chuchu', 0.8),
#  ('Cursed Bokoblin', 0.8),
#  ('Decayed Guardian', 0.8),
#  ('Guardian Scout II', 0.8),
#  ('Stone Pebblit', 0.8),
#  ('Molduking', 0.8),
#  ('Silver Lizalfos', 0.8181818181818182),
#  ('Stone Talus', 0.8181818181818182),
#  ('Rivan', 0.8333333333333334),
#  ('Perda', 0.8333333333333334),
#  ('Amira', 0.8333333333333334),
#  ('Blizzrobe', 0.8333333333333334),
#  ('Blue-Maned Lynel', 0.8333333333333334),
#  ('Cursed Moblin', 0.8333333333333334),
#  ('Fireblight Ganon', 0.875),
#  ('Kass', 0.8888888888888888),
#  ('Blue Lizalfos', 0.8888888888888888),
#  ('Stalmoblin', 0.9),
#  ('Moblin', 0.9090909090909091),
#  ('Lizalfos', 0.9230769230769231),
#  ('Ice-Breath Lizalfos', 1.0),
#  ('Black Lizalfos', 1.0),
#  ('Blue Bokoblin', 1.0),
#  ('Black Bokoblin', 1.0),
#  ('Guardian Stalker', 1.0),
#  ('Hinox', 1.0),
#  ('Windblight Ganon', 1.0),
#  ('Thunderblight Ganon', 1.0),
#  ('Black Moblin', 1.0),
#  ('Blue Moblin', 1.0),
#  ('Golden Bokoblin', 1.0),
#  ('Keese', 1.0),
#  ('Silver Bokoblin', 1.0),
#  ('Silver Lynel', 1.0),
#  ('Dinraal', 1.0),
#  ('Patricia', 1.0),
#  ('Buliara', 1.0),
#  ('Nack', 1.0),
#  ('Igneo Pebblit', 1.0),
#  ('Electric Lizalfos', 1.1111111111111112),
#  ('Fire-Breath Lizalfos', 1.1111111111111112),
#  ('Golden Lizalfos', 1.125),
#  ('Stalkoblin', 1.125),
#  ('Revali', 1.1428571428571428),
#  ('Yunobo', 1.1666666666666667),
#  ('Waterblight Ganon', 1.1666666666666667),
#  ('Electric Keese', 1.2),
#  ('Farosh', 1.25),
#  ('Naydra', 1.25),
#  ('Dmitri', 1.25),
#  ('Rotana', 1.25),
#  ('Fire Chuchu', 1.25),
#  ('Ice Keese', 1.25),
#  ('Robbie', 1.3333333333333333),
#  ('Impa', 1.4),
#  ('Bolson', 1.4),
#  ('Fire Keese', 1.5),
#  ('Ice Chuchu', 1.5),
#  ('King Rhoam', 1.6666666666666667),
#  ('King Dorephan', 1.6666666666666667),
#  ('Old Man', 1.75),
#  ('Vilia', 1.75),
#  ('Mipha', 1.875),
#  ('Purah', 1.8888888888888888),
#  ('Hudson', 2.0),
#  ('Bokoblin', 2.1),
#  ('Sidon', 2.3333333333333335),
#  ('Ashai', 2.6),
#  ('Princess Zelda', 3.25),
#  ('Kilton', 3.25),
#  ('Riju', 4.6),
#  ('Calamity Ganon', 12.25),
#  ('Link', 38.6)]

# %%
avg_degree_ratio = np.mean(list(in_out_ratio.values()))
print('The average in-degree is:',avg_in_degree)
print('The average degree ratio is:',avg_degree_ratio)
# Out:
# The average in-degree is: 3.678227360308285
# The average degree ratio is: 0.8665369751576649

# %% [markdown]
# Generally, many nodes have high out-degree with few incoming connections. And they are all basically NPC instead of main characters.

# %% [markdown]
# ## Are there any nodes with high in-degree and few outcoming connections?

# %% [markdown]
# Similarly, we can use $ratio_{out-in}=\frac{out-degree-amount}{in-degree-amount}$ to find nodes with great contrary between in-degree and out-degree. The smaller $ratio_{out-in}$ is, the bigger the contrary, which means high out-degree and few incoming connections.

# %%
# save the ratio in a dict
out_in_ratio = {}

for i,j in sort_by_value(dict(dir_larG.in_degree())):
    # For high out-degree nodes, I choose those above average out-degree
    if (dir_larG.out_degree[i] != 0) & (j != 0) & (j>avg_in_degree):
        out_in_ratio[i] = dir_larG.out_degree[i]/j
        
# output this dict values from low to high
sorted(out_in_ratio.items(),  key=lambda d: d[1], reverse=False)
# Out:
# [('Link', 0.025906735751295335),
#  ('Hylia', 0.029850746268656716),
#  ('Calamity Ganon', 0.08163265306122448),
#  ('Sky Octorok', 0.2),
#  ('Riju', 0.21739130434782608),
#  ('Princess Zelda', 0.3076923076923077),
#  ('Kilton', 0.3076923076923077),
#  ('Bludo', 0.3333333333333333),
#  ('Ashai', 0.38461538461538464),
#  ('Olkin', 0.4),
#  ('Sidon', 0.42857142857142855),
#  ('Bokoblin', 0.47619047619047616),
#  ('Hudson', 0.5),
#  ('Epona', 0.5),
#  ('Rhondson', 0.5),
#  ('Kaneli', 0.5),
#  ('Karin', 0.5),
#  ('Master Kohga', 0.5),
#  ('Purah', 0.5294117647058824),
#  ('Mipha', 0.5333333333333333),
#  ('Old Man', 0.5714285714285714),
#  ('Vilia', 0.5714285714285714),
#  ('King Rhoam', 0.6),
#  ('King Dorephan', 0.6),
#  ('Sayge', 0.6),
#  ('Electric Chuchu', 0.6),
#  ('Sentry', 0.6),
#  ('White-Maned Lynel', 0.6),
#  ('Fire Keese', 0.6666666666666666),
#  ('Ice Chuchu', 0.6666666666666666),
#  ('Impa', 0.7142857142857143),
#  ('Bolson', 0.7142857142857143),
#  ('Robbie', 0.75),
#  ('Gleema', 0.75),
#  ('Kaifa', 0.75),
#  ('Teake', 0.75),
#  ('Dento', 0.75),
#  ('Stalnox', 0.75),
#  ('Farosh', 0.8),
#  ('Naydra', 0.8),
#  ('Dmitri', 0.8),
#  ('Rotana', 0.8),
#  ('Fire Chuchu', 0.8),
#  ('Ice Keese', 0.8),
#  ('Electric Keese', 0.8333333333333334),
#  ('Yunobo', 0.8571428571428571),
#  ('Waterblight Ganon', 0.8571428571428571),
#  ('Revali', 0.875),
#  ('Golden Lizalfos', 0.8888888888888888),
#  ('Stalkoblin', 0.8888888888888888),
#  ('Electric Lizalfos', 0.9),
#  ('Fire-Breath Lizalfos', 0.9),
#  ('Ice-Breath Lizalfos', 1.0),
#  ('Black Lizalfos', 1.0),
#  ('Blue Bokoblin', 1.0),
#  ('Black Bokoblin', 1.0),
#  ('Guardian Stalker', 1.0),
#  ('Hinox', 1.0),
#  ('Windblight Ganon', 1.0),
#  ('Thunderblight Ganon', 1.0),
#  ('Black Moblin', 1.0),
#  ('Blue Moblin', 1.0),
#  ('Golden Bokoblin', 1.0),
#  ('Keese', 1.0),
#  ('Silver Bokoblin', 1.0),
#  ('Silver Lynel', 1.0),
#  ('Dinraal', 1.0),
#  ('Patricia', 1.0),
#  ('Buliara', 1.0),
#  ('Nack', 1.0),
#  ('Igneo Pebblit', 1.0),
#  ('Lizalfos', 1.0833333333333333),
#  ('Moblin', 1.1),
#  ('Stalmoblin', 1.1111111111111112),
#  ('Kass', 1.125),
#  ('Blue Lizalfos', 1.125),
#  ('Fireblight Ganon', 1.1428571428571428),
#  ('Rivan', 1.2),
#  ('Perda', 1.2),
#  ('Amira', 1.2),
#  ('Blizzrobe', 1.2),
#  ('Blue-Maned Lynel', 1.2),
#  ('Cursed Moblin', 1.2),
#  ('Silver Lizalfos', 1.2222222222222223),
#  ('Stone Talus', 1.2222222222222223),
#  ('Lynel', 1.25),
#  ('Jana', 1.25),
#  ('Dalia', 1.25),
#  ('Makure', 1.25),
#  ('Yaido', 1.25),
#  ('Reede', 1.25),
#  ('Cotera', 1.25),
#  ('Darton', 1.25),
#  ('Shibo', 1.25),
#  ('Steen', 1.25),
#  ('Chuchu', 1.25),
#  ('Cursed Bokoblin', 1.25),
#  ('Decayed Guardian', 1.25),
#  ('Guardian Scout II', 1.25),
#  ('Stone Pebblit', 1.25),
#  ('Molduking', 1.25),
#  ('Urbosa', 1.2857142857142858),
#  ('Cursed Lizalfos', 1.2857142857142858),
#  ('Stalizalfos', 1.3333333333333333),
#  ('Igneo Talus', 1.3333333333333333),
#  ('Pearle', 1.4),
#  ('Nikki', 1.4),
#  ('Paya', 1.4),
#  ('Golden Lynel', 1.4),
#  ('Guardian Skywatcher', 1.4),
#  ('Guardian Turret', 1.4),
#  ('Silver Moblin', 1.4),
#  ('Thunder Wizzrobe', 1.4),
#  ('Water Octorok', 1.4),
#  ('Frost Talus', 1.4),
#  ('Daruk', 1.4285714285714286),
#  ('Dorian', 1.5),
#  ('Jerrin', 1.5),
#  ('Barta', 1.5),
#  ('Kalani', 1.5),
#  ('Trello', 1.5),
#  ('Forest Octorok', 1.5),
#  ('Meteo Wizzrobe', 1.5),
#  ('Rock Octorok', 1.5),
#  ('Snow Octorok', 1.5),
#  ('Treasure Octorok', 1.5),
#  ('Teba', 1.6),
#  ('Azu', 1.6),
#  ('Golden Moblin', 1.6),
#  ('Tumbo', 1.75),
#  ('Ice Wizzrobe', 1.75),
#  ('Igneo Talus Titan', 1.75),
#  ('Fire Wizzrobe', 1.8),
#  ('Yiga Footsoldier', 1.8),
#  ('Nanna', 2.0)]

# %%
avg_degree_ratio = np.mean(list(out_in_ratio.values()))
print('The average out-degree is:',avg_out_degree)
print('The average degree ratio is:',avg_degree_ratio)
# Out:
# The average out-degree is: 3.678227360308285
# The average degree ratio is: 1.0200680978084065

# %% [markdown]
# Link, Hylia, Calamity Ganon have overwhelming in-degree compared with outcoming connections.Amazingly, average in-degree and average out-degree is of same number.

# %% [markdown]
# ## From the plot of the network (in Exercise 3), we can see that 2 nodes with highest degrees (other than Link) have many common neighbors.
#
# ### Can you identify who these characters are? Are they opponents? How many common neighbors do they have?

# %%
from collections import Counter
neig = dict(Counter(Link_neig+HL_neig+CG_neig))
print ({key:value for key,value in neig.items()if value > 1})
# Out:
# {'Princess Zelda': 3, 'Impa': 2, 'Calamity Ganon': 2, 'Link': 2}

# %%
# common neighbors
def find_common_neighbors(a,b):
    common_neighbor_lst = []
    for i in a:
        for j in b:
            if i == j:
                common_neighbor_lst.append(a)
    return len(common_neighbor_lst)

# %%
print('Link and Hylia:',find_common_neighbors(Link_neig,HL_neig))
print('Link and Calamity Ganon:',find_common_neighbors(Link_neig,CG_neig))
print('Calamity Ganon and Hylia:',find_common_neighbors(HL_neig,CG_neig))
# Out:
# Link and Hylia: 2
# Link and Calamity Ganon: 3
# Calamity Ganon and Hylia: 1

# %% [markdown]
# ### Can you characterize the common neighbors in terms of their Gender and Race? What about their Zelda Wiki pages (do they have a specific role in the BotW story)?

# %% [markdown]
# **characterize the common neighbors in terms of their Gender**

# %%
# extract nodes according to Gender
male_nodes = [n for (n,rl) in \
    nx.get_node_attributes(larG,'gender').items() if rl == 'male']
female_nodes = [n for (n,rl) in \
    nx.get_node_attributes(larG,'gender').items() if rl in ('female')]
# find all the remaining nodes.
unknown_nodes = list(set(larG.nodes()) - set(ally_nodes) - set(enemy_nodes))
gender_nodes = unknown_nodes+male_nodes+female_nodes

# %% [markdown]
# **characterize the common neighbors in terms of their Gender**

# %%
# extract nodes according to Race

# %%
# Set color according to Gender/Race

# %% [markdown]
# # Part B: Advanced tools

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### the average, median, mode, minimum and maximum value of the in-degree? And of the out-degree?

# %%
# The value of average in-degree has been calculated in 4.2
median_in_degree = np.median(list(dict(dir_larG.in_degree).values()))
mode_in_degree =  stats.mode(list(dict(dir_larG.in_degree).values()))
min_in_degree = np.min(list(dict(dir_larG.in_degree).values()))
max_in_degree = np.max(list(dict(dir_larG.in_degree).values()))
print('The avg_in_degree is:',avg_in_degree)
print('The median_in_degree is:',median_in_degree)
print('The mode_in_degree is:',mode_in_degree)
print('The min_in_degree is:',min_in_degree)
print('The max_in_degree is:',max_in_degree)
# Out:
# The avg_in_degree is: 3.678227360308285
# The median_in_degree is: 2.0
# The mode_in_degree is: ModeResult(mode=array([1]), count=array([158]))
# The min_in_degree is: 0
# The max_in_degree is: 386

# %% [markdown]
# The mode of in-degree is larger than the median, which indicates the in-degree had has an unbalanced distribution. This is because the in-degree extreme value is distinctively larger than the average value.

# %%
# The value of average out-degree has been calculated in 4.2
median_out_degree = np.median(list(dict(dir_larG.out_degree).values()))
mode_out_degree =  stats.mode(list(dict(dir_larG.out_degree).values()))
min_out_degree = np.min(list(dict(dir_larG.out_degree).values()))
max_out_degree = np.max(list(dict(dir_larG.out_degree).values()))
print('The avg_out_degree is:',avg_out_degree)
print('The median_out_degree is:',median_out_degree)
print('The mode_out_degree is:',mode_out_degree)
print('The min_out_degree is:',min_out_degree)
print('The max_out_degree is:',max_out_degree)
# Out:
# The avg_out_degree is: 3.678227360308285
# The median_out_degree is: 4.0
# The mode_out_degree is: ModeResult(mode=array([4]), count=array([122]))
# The min_out_degree is: 0
# The max_out_degree is: 14

# %% [markdown]
# The mode value of the out-degree is as same as the median value of the out-degree and close to its average value. So out-degree distribution is more flat than that of in-degree.

# %% [markdown]
# **On top of that, calculate same statistics separately for the network that is spanned only by allies and only by opponents (i.e. enemies and bosses together). How do you interpret the results?**

# %% [markdown]
# **Repeat the last step, but for the network that is spanned only by females and only by males. How do you interpret the results?**

# %% [markdown]
# ### look at the exponent of the degree distribution

# %%
data = list(dict(dir_larG.in_degree).values())
fit1 = powerlaw.Fit(data)
print('The exponent of the in-degree distribution is:',fit1.alpha)
data = list(dict(dir_larG.out_degree).values())
fit2 = powerlaw.Fit(data)
print('The exponent of the out-degree distribution is:',fit2.alpha)
# Out:
# Calculating best minimal value for power law fit
# The exponent of the in-degree distribution is: 3.344225052789243
# Calculating best minimal value for power law fit
# The exponent of the out-degree distribution is: 4.800118075013094
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Values less than or equal to 0 in data. Throwing out 0 or negative values

# %% [markdown]
# The exponent of the in-degree distribution is smaller than that of out-degree, which implies that ...

# %% [markdown]
# ### Plot a scatter plot of the the in- versus out- degree for all characters.

# %%
in_x = list(dict(dir_larG.in_degree).values())
out_y = list(dict(dir_larG.out_degree).values())
    
ax = plt.scatter(in_x,out_y)
plt.xlabel('in-degree')
plt.ylabel('out-degree')
plt.show()

# %% [markdown]
# ### Plot a heatmap (Hint here) of the the in- versus out- degree for all characters.

# %%
plt.hist2d(in_x,out_y,bins=30)
plt.show()

# %% [markdown]
# ### Why do you think I want you guys to use a directed graph? Could have we used an undirected graph instead?

# %% [markdown]
# By using a directed graph, we can analyse the links between nodes from two perspective,namely in and out. If we use undirected graph, then the links between nodes will have no direction, which means we can't tell the difference between in and out of degrees.The in- and out- degrees will be calculated as a whole for every node they connect.

# %% [markdown]
# ### We have one more metric that we did not use. The node-attribute content lenght. There are two things we can investigate here.
# **Firstly, we can verify that more text means more links. If that's true the length should correlate with out-degree.**

# %%
each_length = nx.get_node_attributes(larG,'content_length').values()
plt.scatter(each_length,out_y)

# %% [markdown]
# It's not true. The graph shows the length and out-degree has no correlation.

# %% [markdown]
# **Secondly, and more interestingly, it could be that longer texts means more famous characters. And that means more in-links.**

# %%
plt.scatter(each_length,in_x)

# %% [markdown]
# Generally, the node with larger content length doesn't really mean this character is famous. However, there are outliers fitting our assumption. The node wiki with about 15000 words has the highest in-degree(400).

# %% [markdown]
# ## Exercise 2: Centralities, assortativity and more

# %% [markdown]
# ### Find the 5 most central characters according to degree centrality.

# %%
DC = sort_by_value(nx.degree_centrality(larG))
DC[0:5]
# Out:
# [('Link', 0.750965250965251),
#  ('Calamity Ganon', 0.19498069498069498),
#  ('Hylia', 0.12934362934362933),
#  ('Princess Zelda', 0.052123552123552123),
#  ('Riju', 0.04633204633204634)]

# %% [markdown]
# ### Find the 5 most central characters according to betweenness centrality.

# %%
BC = sort_by_value(nx.betweenness_centrality(larG))
BC[0:5]
# Out:
# [('Link', 0.9316389590711456),
#  ('Calamity Ganon', 0.03435337267839812),
#  ('Bludo', 0.024486824852638235),
#  ('Daruk', 0.021246942249524364),
#  ('Kass', 0.017268940975680477)]

# %% [markdown]
# ### Find the 5 most central characters according to eigenvector centrality.

# %%
EC = sort_by_value(nx.eigenvector_centrality(larG))
EC[0:5]
# Out:
# [('Link', 0.632328831270225),
#  ('Calamity Ganon', 0.22902611665058334),
#  ('Hylia', 0.15726516739574956),
#  ('Princess Zelda', 0.09149864613645398),
#  ('Impa', 0.07318001746608704)]

# %% [markdown]
# **Repeat Exercise A2 or A3 use eigenvector centrality to define the size of the node.**

# %%
options_node2 = {
    'nodelist': nodelst,
    'node_color': colors,
    # set node-size depending on options_node_eigenvector
    'node_size':[v[1]*3000 for v in EC],
    'alpha':0.9,
}

plt.figure(figsize=(12,12))

# draw nodes
nx.draw_networkx_nodes(larG,positions, **options_node2)

# draw edges
options_edge = {
    'edge_color':edge_colors,
}
nx.draw_networkx_edges(larG,positions, **options_edge)

# cancel axis
plt.axis('off')
plt.show()

# %% [markdown]
# **What role do you imagine characters with high wikipedia graph eigenvector centrality play?**

# %% [markdown]
#  ### Is the undirected version of the graph assortative with respect to degree? (e.g. do high-degree characters tend to link to other high-degree characters, and low-degree characters to other low-degree characters?). Provide an interpretation of your answer.

# %% [markdown]
# ### Is the undirected version of the graph assortative with respect do the content length nodal properties? (e.g. do characters with long Zelda Wiki pages tend to link to other characters with long Wiki pages, and vice versa?. Hint: Use this function. Provide an interpretation of your answer.

# %% [markdown]
# ### Is the undirected version of the graph assortative with respect to Role, Race, and Gender? (e.g. allies tend to link to allies, bosses to bosses, and enemies to enemies). Provide an interpretation of your answer.

# %% [markdown]
# ### What is the average shortest path length? Is it similar to the one of a random graph with the same number of nodes N and probablity of connection p?

# %% [markdown]
# ## Exercise 3: Is the role of a character important for the network structure?

# %%
# Part B: Advanced tools

## Exercise 1

### the average, median, mode, minimum and maximum value of the in-degree? And of the out-degree?



### look at the exponent of the degree distribution



### Plot a scatter plot of the the in- versus out- degree for all characters.



### Plot a heatmap (Hint here) of the the in- versus out- degree for all characters. 





## Exercise 2: Centralities, assortativity and more



## Exercise 3: Is the role of a character important for the network structure?

colors = []
for i in range(len(gender_nodes)):
    if i < len(male_nodes):
        colors.append('#41b6e6')
    elif i < len(male_nodes+female_nodes):
        colors.append('#e74c3c')
    else:
        colors.append('#7A57D1')

# %% [markdown]
# ## Exercise 3: Is the role of a character important for the network structure? Let us explore if and how it shapes the network (use the undirected network).
